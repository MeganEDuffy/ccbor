# %%
# read from csv 
biweek = pd.read_csv("/home/millieginty/Documents/git-repos/ccbor/data/biweekly/ccbor-biweekly-stolz.csv", parse_dates=['date'])

## Split the dataframe into site-specific dataframes

biweek1 = biweek[biweek['site'] == 1] # West Branch Alum Creek, upstream
biweek2 = biweek[biweek['site'] == 2] # West Branch Alum Creek, downstream 1
biweek3 = biweek[biweek['site'] == 3] # West Branch Alum Creek, downstream 2
biweek4 = biweek[biweek['site'] == 4] # Headwaters Alum Creek, upstream
biweek5 = biweek[biweek['site'] == 5] # Headwaters Alum Creek, downstream
biweek6 = biweek[biweek['site'] == 6] # Headwaters Alum Creek, intermediate 2
biweek7 = biweek[biweek['site'] == 7] # Headwaters Alum Creek, intermediate 1
biweek8 = biweek[biweek['site'] == 8] # Headwaters Big Walnut Creek, downstream
biweek9 = biweek[biweek['site'] == 9] # Little Walnut Creek, downstream

# %%
import os
os.getcwd()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
from scipy.stats import kde
from matplotlib import cm
import datetime
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import re

fig, axes = plt.subplots(4, 4, figsize=(20, 20), sharey = True)
fig.suptitle('Alum Creek water quality', fontsize=30, y = 1.04)
fig.tight_layout(pad=2.08, w_pad=2)

SMALL_SIZE = 18
MEDIUM_SIZE = 20
BIGGER_SIZE = 24

# Site 4
axes[0,0].plot(biweek4.date, biweek4.CCBOR_TDS, c = '#dd1c77', label='Total dissolved solids') 

ax0 = axes[0,0].twinx() # Add another y axis
ax0.set_ylim([10, 50]) # set y axis range
biweek4.plot.scatter(x="date", y="Chloride", ax=ax0, c = 'Blue', s = 100, label='Chloride') # Add in chloride
ax0.tick_params(axis='y', labelsize=18)
#ax0.set_ylabel('Chloride (mg/L)', size=MEDIUM_SIZE)
ax0.set_ylabel('')
ax0.legend(loc='upper right', bbox_to_anchor=(0.925, 0.88), fontsize = SMALL_SIZE)

axes[0,0].set_xticklabels(biweek4.date, rotation = 85, size=SMALL_SIZE)
axes[0,0].set_ylim([0, 1000]) # set y axis range
axes[0,0].tick_params(axis='y', labelsize=18)
axes[0,0].set_ylabel('Total dissolved solids (mg/L)', size=MEDIUM_SIZE)
axes[0,0].set_title('Site #4: Upstream', size=BIGGER_SIZE)
axes[0,0].legend(loc='upper right', fontsize = SMALL_SIZE)

axes[0,0].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[0,0].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

# Site 7
axes[0,1].plot(biweek7.date, biweek7.CCBOR_TDS, c = '#dd1c77')

ax1 = axes[0,1].twinx() # Add another y axis
ax1.set_ylim([10, 50]) # set y axis range
biweek7.plot.scatter(x="date", y="Chloride", ax=ax1, c = 'Blue', s = 100) # Add in chloride
ax1.tick_params(axis='y', labelsize=18)
#ax1.set_ylabel('Chloride (mg/L)', size=MEDIUM_SIZE)
ax1.set_ylabel('')

axes[0,1].set_xticklabels(biweek7.date, rotation = 85, size=SMALL_SIZE)
axes[0,1].set_title('Site #7: Downstream 1', size=BIGGER_SIZE)


axes[0,1].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[0,1].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
    
# Site 6
axes[0,2].plot(biweek6.date, biweek6.CCBOR_TDS, c = '#dd1c77')

ax2 = axes[0,2].twinx() # Add another y axis
ax2.set_ylim([10, 50]) # set y axis range
biweek6.plot.scatter(x="date", y="Chloride", ax=ax2, c = 'Blue', s = 100) # Add in chloride
ax2.tick_params(axis='y', labelsize=18)
#ax2.set_ylabel('Chloride (mg/L)', size=MEDIUM_SIZE)

axes[0,2].set_xticklabels(biweek6.date, rotation = 85, size=SMALL_SIZE)
axes[0,2].set_title('Site #6: Downstream 2', size=BIGGER_SIZE)

axes[0,2].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[0,2].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
    
# Site 5
axes[0,3].plot(biweek5.date, biweek5.CCBOR_TDS, c = '#dd1c77')

ax3 = axes[0,3].twinx() # Add another y axis
ax3.set_ylim([10, 50]) # set y axis range
biweek5.plot.scatter(x="date", y="Chloride", ax=ax3, c = 'Blue', s = 100) # Add in chloride
ax3.tick_params(axis='y', labelsize=18)
ax3.set_ylabel('Chloride (mg/L)', size=MEDIUM_SIZE)

axes[0,3].set_xticklabels(biweek5.date, rotation = 85, size=SMALL_SIZE)
axes[0,3].set_title('Site #5: Downstream 3', size=BIGGER_SIZE)

axes[0,3].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[0,3].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
    
############ B sulfate
# Site 4
axes[1,0].plot(biweek4.date, biweek4.CCBOR_TDS, c = '#dd1c77', label='Total dissolved solids') 

ax4 = axes[1,0].twinx() # Add another y axis
ax0.set_ylim([10, 50]) # set y axis range
biweek4.plot.scatter(x="date", y="Sulfate", ax=ax4, c = '#8856a7', s = 100, label='Sulfate') # Add in Sulfate
ax0.tick_params(axis='y', labelsize=18)
#ax0.set_ylabel('Sulfate (mg/L)', size=MEDIUM_SIZE)
ax0.set_ylabel('')
ax0.legend(loc='upper right', bbox_to_anchor=(0.925, 0.88), fontsize = SMALL_SIZE)

axes[1,0].set_xticklabels(biweek4.date, rotation = 85, size=SMALL_SIZE)
axes[1,0].set_ylim([0, 1000]) # set y axis range
axes[1,0].tick_params(axis='y', labelsize=18)
axes[1,0].set_ylabel('Total dissolved solids (mg/L)', size=MEDIUM_SIZE)
axes[1,0].set_title('Site #4: Upstream', size=BIGGER_SIZE)
axes[1,0].legend(loc='upper right', fontsize = SMALL_SIZE)

axes[1,0].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[1,0].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

# Site 7
axes[1,1].plot(biweek7.date, biweek7.CCBOR_TDS, c = '#dd1c77')

ax5 = axes[1,1].twinx() # Add another y axis
ax1.set_ylim([10, 50]) # set y axis range
biweek7.plot.scatter(x="date", y="Sulfate", ax=ax5, c = '#8856a7', s = 100) # Add in Sulfate
ax1.tick_params(axis='y', labelsize=18)
#ax1.set_ylabel('Sulfate (mg/L)', size=MEDIUM_SIZE)
ax1.set_ylabel('')

axes[1,1].set_xticklabels(biweek7.date, rotation = 85, size=SMALL_SIZE)
axes[1,1].set_title('Site #7: Downstream 1', size=BIGGER_SIZE)


axes[1,1].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[1,1].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
    
# Site 6
axes[1,2].plot(biweek6.date, biweek6.CCBOR_TDS, c = '#dd1c77')

ax6 = axes[1,2].twinx() # Add another y axis
ax2.set_ylim([10, 50]) # set y axis range
biweek6.plot.scatter(x="date", y="Sulfate", ax=ax6, c = '#8856a7', s = 100) # Add in Sulfate
ax2.tick_params(axis='y', labelsize=18)
#ax2.set_ylabel('Sulfate (mg/L)', size=MEDIUM_SIZE)

axes[1,2].set_xticklabels(biweek6.date, rotation = 85, size=SMALL_SIZE)
axes[1,2].set_title('Site #6: Downstream 2', size=BIGGER_SIZE)

axes[1,2].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[1,2].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
    
# Site 5
axes[1,3].plot(biweek5.date, biweek5.CCBOR_TDS, c = '#dd1c77')

ax7 = axes[1,3].twinx() # Add another y axis
ax3.set_ylim([10, 50]) # set y axis range
biweek5.plot.scatter(x="date", y="Sulfate", ax=ax7, c = '#8856a7', s = 100) # Add in Sulfate
ax3.tick_params(axis='y', labelsize=18)
ax3.set_ylabel('Sulfate (mg/L)', size=MEDIUM_SIZE)

axes[1,3].set_xticklabels(biweek5.date, rotation = 85, size=SMALL_SIZE)
axes[1,3].set_title('Site #5: Downstream 3', size=BIGGER_SIZE)

axes[1,3].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[1,3].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

# %%
# Site 4
axes[1,0].plot(biweek4.date, biweek4.CCBOR_TDS, c = '#dd1c77', label='Total dissolved solids') 

ax4 = axes[1,0].twinx() # Add another y axis
ax0.set_ylim([10, 50]) # set y axis range
biweek4.plot.scatter(x="date", y="Sulfate", ax=ax4, c = '#8856a7', s = 100, label='Sulfate') # Add in Sulfate
ax0.tick_params(axis='y', labelsize=18)
#ax0.set_ylabel('Sulfate (mg/L)', size=MEDIUM_SIZE)
ax0.set_ylabel('')
ax0.legend(loc='upper right', bbox_to_anchor=(0.925, 0.88), fontsize = SMALL_SIZE)

axes[1,0].set_xticklabels(biweek4.date, rotation = 85, size=SMALL_SIZE)
axes[1,0].set_ylim([0, 1000]) # set y axis range
axes[1,0].tick_params(axis='y', labelsize=18)
axes[1,0].set_ylabel('Total dissolved solids (mg/L)', size=MEDIUM_SIZE)
axes[1,0].set_title('Site #4: Upstream', size=BIGGER_SIZE)
axes[1,0].legend(loc='upper right', fontsize = SMALL_SIZE)

axes[1,0].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[1,0].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

# Site 7
axes[1,1].plot(biweek7.date, biweek7.CCBOR_TDS, c = '#dd1c77')

ax5 = axes[1,1].twinx() # Add another y axis
ax1.set_ylim([10, 50]) # set y axis range
biweek7.plot.scatter(x="date", y="Sulfate", ax=ax5, c = '#8856a7', s = 100) # Add in Sulfate
ax1.tick_params(axis='y', labelsize=18)
#ax1.set_ylabel('Sulfate (mg/L)', size=MEDIUM_SIZE)
ax1.set_ylabel('')

axes[1,1].set_xticklabels(biweek7.date, rotation = 85, size=SMALL_SIZE)
axes[1,1].set_title('Site #7: Downstream 1', size=BIGGER_SIZE)


axes[1,1].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[1,1].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
    
# Site 6
axes[1,2].plot(biweek6.date, biweek6.CCBOR_TDS, c = '#dd1c77')

ax6 = axes[1,2].twinx() # Add another y axis
ax2.set_ylim([10, 50]) # set y axis range
biweek6.plot.scatter(x="date", y="Sulfate", ax=ax6, c = '#8856a7', s = 100) # Add in Sulfate
ax2.tick_params(axis='y', labelsize=18)
#ax2.set_ylabel('Sulfate (mg/L)', size=MEDIUM_SIZE)

axes[1,2].set_xticklabels(biweek6.date, rotation = 85, size=SMALL_SIZE)
axes[1,2].set_title('Site #6: Downstream 2', size=BIGGER_SIZE)

axes[1,2].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[1,2].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
    
# Site 5
axes[1,3].plot(biweek5.date, biweek5.CCBOR_TDS, c = '#dd1c77')

ax7 = axes[1,3].twinx() # Add another y axis
ax3.set_ylim([10, 50]) # set y axis range
biweek5.plot.scatter(x="date", y="Sulfate", ax=ax7, c = '#8856a7', s = 100) # Add in Sulfate
ax3.tick_params(axis='y', labelsize=18)
ax3.set_ylabel('Sulfate (mg/L)', size=MEDIUM_SIZE)

axes[1,3].set_xticklabels(biweek5.date, rotation = 85, size=SMALL_SIZE)
axes[1,3].set_title('Site #5: Downstream 3', size=BIGGER_SIZE)

axes[1,3].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
for label in axes[1,3].get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
